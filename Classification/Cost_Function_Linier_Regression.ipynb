# %% [markdown]
# <a href="https://colab.research.google.com/github/fidamaisahana/MachineLearning/blob/main/Classification/Cost_Function_Linier_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x_train = np.array([1.0, 2.0, 4.0])
y_train = np.array([300.0, 500.0, 800.0])

plt.scatter(x_train, y_train)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
w = 180
b = 100

m = x_train.shape[0]
cost_sum = 0

for i in range(m):
    f_wb = w * x_train[i] + b
    cost = (f_wb - y_train[i])**2
    cost_sum = cost_sum + cost

total_cost = (1 / (2 * m)) * cost_sum
total_cost
# Out:
# 400.0

# %%
def compute_cost(x, y, w, b):
    m = x.shape[0]
    cost_sum = 0

    for i in range(m):
        f_wb = w * x[i] + b
        cost = (f_wb - y[i]) ** 2
        cost_sum = cost_sum + cost

    total_cost = (1 / (2 * m)) * cost_sum
    return total_cost

# %%
compute_cost(x_train, y_train, 180, 100)
# Out:
# 400.0

# %%
compute_cost(x_train, y_train, 100, 100)
# Out:
# 23333.333333333332

# %%
compute_cost(x_train, y_train, 300, 100)
# Out:
# 50000.0
